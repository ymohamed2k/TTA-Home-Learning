# %%
import pandas as pd

# %%
holiday = pd.read_csv("Holiday.csv")
print(holiday)
# Out:
#     Destinations  Feedback  Average_Rating  All_Inclusive        City
# 0         France         8               8             10       Paris
# 1          Japan         9               8             18       Tokyo
# 2            UAE         8               9             13       Dubai
# 3        America         7               9             15       Miami
# 4   South Africa         8               8              8   Cape City
# 5       Thailand         8               7              4     Bangkok
# 6          Italy         9               8              8      Venice
# 7        England         8               7             14      London
# 8          Egypt         9               7              7  Alexandria
# 9         Sweden         8               8              5  Gothenburg
# 10   Philippines         7               7              3      Manila
# 11     Australia         7               8              5      Sydney
# ...

# %%
holiday.shape
# Out:
# (15, 5)

# %%
holiday.iloc[3:9]
# Out:
#    Destinations  Feedback  Average_Rating  All_Inclusive        City
# 3       America         7               9             15       Miami
# 4  South Africa         8               8              8   Cape City
# 5      Thailand         8               7              4     Bangkok
# 6         Italy         9               8              8      Venice
# 7       England         8               7             14      London
# 8         Egypt         9               7              7  Alexandria

# %%
holiday["All_Inclusive"].mean()
# Out:
# 8.533333333333333

# %%
holiday["Feedback"].min()
# Out:
# 7

# %%
holiday.sort_values(["Feedback"])
# Out:
#     Destinations  Feedback  Average_Rating  All_Inclusive        City
# 3        America         7               9             15       Miami
# 10   Philippines         7               7              3      Manila
# 11     Australia         7               8              5      Sydney
# 13         China         7               8              8     Beijing
# 0         France         8               8             10       Paris
# 2            UAE         8               9             13       Dubai
# 4   South Africa         8               8              8   Cape City
# 5       Thailand         8               7              4     Bangkok
# 7        England         8               7             14      London
# 9         Sweden         8               8              5  Gothenburg
# 14        Brazil         8               7              6         Rio
# 1          Japan         9               8             18       Tokyo
# ...

# %%
holiday["Feedback"].max()

# %%
holiday.sort_values(["Feedback"], ascending=False)
# Out:
#     Destinations  Feedback  Average_Rating  All_Inclusive        City
# 1          Japan         9               8             18       Tokyo
# 6          Italy         9               8              8      Venice
# 8          Egypt         9               7              7  Alexandria
# 12       Morocco         9               7              4  Casablanca
# 0         France         8               8             10       Paris
# 2            UAE         8               9             13       Dubai
# 4   South Africa         8               8              8   Cape City
# 5       Thailand         8               7              4     Bangkok
# 7        England         8               7             14      London
# 9         Sweden         8               8              5  Gothenburg
# 14        Brazil         8               7              6         Rio
# 3        America         7               9             15       Miami
# ...

# %%
holiday[holiday.All_Inclusive > 9]
# Out:
#   Destinations  Feedback  Average_Rating  All_Inclusive    City
# 0       France         8               8             10   Paris
# 1        Japan         9               8             18   Tokyo
# 2          UAE         8               9             13   Dubai
# 3      America         7               9             15   Miami
# 7      England         8               7             14  London

# %%
holiday[(holiday.All_Inclusive > 9) & (holiday.Feedback > 8)]
# Out:
#   Destinations  Feedback  Average_Rating  All_Inclusive   City
# 1        Japan         9               8             18  Tokyo

# %%
holiday[(holiday.All_Inclusive > 9) & (holiday.Feedback < 2)]
# Out:
# Empty DataFrame
# Columns: [Destinations, Feedback, Average_Rating, All_Inclusive, City]
# Index: []
